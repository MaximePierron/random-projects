# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
cars =  pd.read_csv('auto.csv')

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0    70
# 1  15.0          8         350.0       165.0  3693.0          11.5    70
# 2  18.0          8         318.0       150.0  3436.0          11.0    70
# 3  16.0          8         304.0       150.0  3433.0          12.0    70
# 4  17.0          8         302.0       140.0  3449.0          10.5    70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
unique_regions = cars['origin'].unique()
unique_regions.sort()

# %%
print(unique_regions)
# Out:
# [1 2 3]

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 24.6 KB

# %%
dummy_cylinders = pd.get_dummies(cars['cylinders'], prefix='cyl')

# %%
cars = pd.concat([cars, dummy_cylinders], axis=1)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0    70
# 1  15.0          8         350.0       165.0  3693.0          11.5    70
# 2  18.0          8         318.0       150.0  3436.0          11.0    70
# 3  16.0          8         304.0       150.0  3433.0          12.0    70
# 4  17.0          8         302.0       140.0  3449.0          10.5    70
#
#    origin  cyl_3  cyl_4  cyl_5  cyl_6  cyl_8
# 0       1  False  False  False  False   True
# 1       1  False  False  False  False   True
# 2       1  False  False  False  False   True
# 3       1  False  False  False  False   True
# 4       1  False  False  False  False   True

# %%
dummy_years = pd.get_dummies(cars['year'], prefix='year')
cars = pd.concat([cars, dummy_years], axis=1)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0    70
# 1  15.0          8         350.0       165.0  3693.0          11.5    70
# 2  18.0          8         318.0       150.0  3436.0          11.0    70
# 3  16.0          8         304.0       150.0  3433.0          12.0    70
# 4  17.0          8         302.0       140.0  3449.0          10.5    70
#
#    origin  cyl_3  cyl_4  ...  year_73  year_74  year_75  year_76  year_77  \
# 0       1  False  False  ...    False    False    False    False    False
# 1       1  False  False  ...    False    False    False    False    False
# 2       1  False  False  ...    False    False    False    False    False
# 3       1  False  False  ...    False    False    False    False    False
# 4       1  False  False  ...    False    False    False    False    False
#
#    year_78  year_79  year_80  year_81  year_82
# 0    False    False    False    False    False
# 1    False    False    False    False    False
# 2    False    False    False    False    False
# 3    False    False    False    False    False
# 4    False    False    False    False    False
#
# [5 rows x 26 columns]

# %%
cars_dummied = cars.drop(['cylinders', 'year'], axis=1)

# %%
shuffled_rows = np.random.permutation(cars_dummied.index)
shuffled_cars = cars_dummied.iloc[shuffled_rows]

# %%
train = shuffled_cars[:int(len(shuffled_cars)*0.7)]
test = shuffled_cars[int(len(shuffled_cars)*0.7):]

# %%
from sklearn.linear_model import LogisticRegression

models = {}
features = [c for c in train.columns if c.startswith('cyl') or c.startswith('year')]

for region in unique_regions:
    model = LogisticRegression(solver='liblinear')
    x_train = train[features]
    y_train = train['origin'] == region

    model.fit(x_train, y_train)
    models[region] = model

# %%
testing_probs = pd.DataFrame(columns=unique_regions)

# %%
for region in unique_regions:
    x_test = test[features]
    predictions = models[region].predict_proba(x_test)[:,1]
    testing_probs[region] = predictions

testing_probs
# Out:
#             1         2         3
# 0    0.959134  0.040470  0.021356
# 1    0.832395  0.082563  0.104225
# 2    0.284430  0.252879  0.463115
# 3    0.797773  0.128896  0.079037
# 4    0.954038  0.045157  0.019532
# ..        ...       ...       ...
# 113  0.953148  0.017648  0.055728
# 114  0.284430  0.252879  0.463115
# 115  0.346430  0.298102  0.324515
# 116  0.245242  0.263948  0.496549
# 117  0.245242  0.263948  0.496549
#
# [118 rows x 3 columns]

# %%
predicted_origins = testing_probs.idxmax(axis=1)

# %%
test['predicted_origin'] = predicted_origins.to_list()

# %%
test.head()
# Out:
#       mpg  displacement  horsepower  weight  acceleration  origin  cyl_3  \
# 164  13.0         302.0       129.0  3169.0          12.0       1  False
# 223  17.5         250.0       110.0  3520.0          16.4       1  False
# 345  34.1          91.0        68.0  1985.0          16.0       3  False
# 151  18.0         250.0       105.0  3459.0          16.0       1  False
# 7    14.0         440.0       215.0  4312.0           8.5       1  False
#
#      cyl_4  cyl_5  cyl_6  ...  year_74  year_75  year_76  year_77  year_78  \
# 164  False  False  False  ...    False     True    False    False    False
# 223  False  False   True  ...    False    False    False     True    False
# 345   True  False  False  ...    False    False    False    False    False
# 151  False  False   True  ...    False     True    False    False    False
# 7    False  False  False  ...    False    False    False    False    False
#
#      year_79  year_80  year_81  year_82  predicted_origin
# 164    False    False    False    False                 1
# 223    False    False    False    False                 1
# 345    False    False     True    False                 3
# 151    False    False    False    False                 1
# 7      False    False    False    False                 1
#
# [5 rows x 25 columns]

# %%
test['good_prediction'] = test['origin'] == test['predicted_origin']

# %%
test.head()
# Out:
#       mpg  displacement  horsepower  weight  acceleration  origin  cyl_3  \
# 164  13.0         302.0       129.0  3169.0          12.0       1  False
# 223  17.5         250.0       110.0  3520.0          16.4       1  False
# 345  34.1          91.0        68.0  1985.0          16.0       3  False
# 151  18.0         250.0       105.0  3459.0          16.0       1  False
# 7    14.0         440.0       215.0  4312.0           8.5       1  False
#
#      cyl_4  cyl_5  cyl_6  ...  year_75  year_76  year_77  year_78  year_79  \
# 164  False  False  False  ...     True    False    False    False    False
# 223  False  False   True  ...    False    False     True    False    False
# 345   True  False  False  ...    False    False    False    False    False
# 151  False  False   True  ...     True    False    False    False    False
# 7    False  False  False  ...    False    False    False    False    False
#
#      year_80  year_81  year_82  predicted_origin  good_prediction
# 164    False    False    False                 1             True
# 223    False    False    False                 1             True
# 345    False     True    False                 3             True
# 151    False    False    False                 1             True
# 7      False    False    False                 1             True
#
# [5 rows x 26 columns]

# %%
tpr = len(test['good_prediction'] == True) / len(test)

# %%
print(tpr)
# Out:
# 1.0
